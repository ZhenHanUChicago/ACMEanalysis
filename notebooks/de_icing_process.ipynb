# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
df = pd.read_table(r"C:\Users\ACME\Downloads\40kcd.txt")
df.columns = ['t', 'K']
df['t'] = pd.to_datetime(df['t'])
df = df.resample('1min', on='t').mean().reset_index()

# %%
df_main = df

# %%
px.line(df_main, x='t', y='K', title='De-icing Process: Without Turbo Pump ---- With Turbo Pump')
